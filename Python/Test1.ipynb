# %%
print("Testing...")
# Out:
# Testing...

# %%
name1 = "Tawfique"
age = 26
print("My name is", name1, "\nI am", age, "years old")
# Out:
# My name is Tawfique
# I am 26 years old

# %%
import sys
print(sys.executable)
# Out:
# d:\Code\.virtual1\Scripts\python.exe

# %%
print("Virtual Environment [Python (.virtual1)] is successfully setup")
# Out:
# Virtual Environment [Python (.virtual1)] is successfully setup
